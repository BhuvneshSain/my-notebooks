# %% [markdown]
# <a href="https://colab.research.google.com/github/BhuvneshSain/my-notebooks/blob/master/Covid_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Covid 19 notebook by Bhuvnesh Sain***
# # Importing Required Packages

# %%
import pandas as pd
import folium

# %% [markdown]
# # Read csv file containing state name with location (latitude,longitude)

# %%
State_With_Loc=pd.read_csv('https://drive.google.com/uc?id=11L8V4ywgRa186AiPxYNfx9Jipuwup8N_&export=download',index_col=0)
State_With_Loc
# Out:
#                                   State.Name   latitude  longitude
# 1                ANDAMAN AND NICOBAR ISLANDS  11.667026  92.735983
# 2                             ANDHRA PRADESH  14.750429  78.570026
# 3                          ARUNACHAL PRADESH  27.100399  93.616601
# 4                                      ASSAM  26.749981  94.216667
# 5                                      BIHAR  25.785414  87.479973
# 6                                 CHANDIGARH  30.719997  76.780006
# 7                               CHHATTISGARH  22.090420  82.159987
# 8   DADRA AND NAGAR HAVELI AND DAMAN AND DIU  20.266578  73.016618
# 9                                      DELHI  28.669993  77.230004
# 10                                       GOA  15.491997  73.818001
# 11                                   HARYANA  28.450006  77.019991
# 12                          HIMACHAL PRADESH  31.100025  77.166597
# 13                         JAMMU AND KASHMIR  34.299959  74.466658
# ...

# %% [markdown]
# # Read csv file containing Covid 19 detailed data with state name

# %%
State_With_Covid_Data =pd.read_csv('https://api.covid19india.org/csv/latest/state_wise.csv')
State_With_Covid_Data
# Out:
#                                        State  ...                                        State_Notes
# 0                                      Total  ...                                                NaN
# 1                                Maharashtra  ...  16 cases were marked as non-covid deaths in MH...
# 2                                 Tamil Nadu  ...  2 deaths cross notified to other states from C...
# 3                                      Delhi  ...  Delhi bulletins in the morning, containing dat...
# 4                                    Gujarat  ...                                                NaN
# 5                              Uttar Pradesh  ...                                                NaN
# 6                                  Rajasthan  ...                                                NaN
# 7                                West Bengal  ...                                                NaN
# ...

# %% [markdown]
# # Remove useless data in Covid 19 dataframe eg. state code

# %%
State_With_Covid_Data=State_With_Covid_Data.iloc[:,:6]
State_With_Covid_Data
# Out:
#                                        State  ...    Last_Updated_Time
# 0                                      Total  ...  30/06/2020 23:11:13
# 1                                Maharashtra  ...  30/06/2020 21:25:14
# 2                                 Tamil Nadu  ...  30/06/2020 18:46:15
# 3                                      Delhi  ...  30/06/2020 22:43:15
# 4                                    Gujarat  ...  30/06/2020 21:03:14
# 5                              Uttar Pradesh  ...  30/06/2020 22:25:15
# 6                                  Rajasthan  ...  30/06/2020 21:25:16
# 7                                West Bengal  ...  30/06/2020 19:49:17
# 8                             Madhya Pradesh  ...  30/06/2020 19:13:15
# 9                                    Haryana  ...  30/06/2020 20:07:16
# 10                          State Unassigned  ...  30/06/2020 09:56:15
# 11                                 Karnataka  ...  30/06/2020 20:07:21
# ...

# %% [markdown]
# # Store the useful data in  variables so that we can access them easily

# %%
Location_Data={}
for name,lat,log in zip(State_With_Loc['State.Name'],State_With_Loc['latitude'],State_With_Loc['longitude']):
    Location_Data[name]=(float(lat),float(log))

# %%
Location_Data
# Out:
# {'ANDAMAN AND NICOBAR ISLANDS': (11.66702557, 92.73598262),
#  'ANDHRA PRADESH': (14.7504291, 78.57002559),
#  'ARUNACHAL PRADESH': (27.10039878, 93.61660071),
#  'ASSAM': (26.7499809, 94.21666744),
#  'BIHAR': (25.78541445, 87.4799727),
#  'CHANDIGARH': (30.71999697, 76.78000565),
#  'CHHATTISGARH': (22.09042035, 82.15998734),
#  'DADRA AND NAGAR HAVELI AND DAMAN AND DIU': (20.26657819, 73.01661779999999),
#  'DELHI': (28.6699929, 77.23000403),
#  'GOA': (15.491997, 73.81800065),
#  'GUJARAT': (22.2587, 71.1924),
#  'HARYANA': (28.45000633, 77.01999101),
#  'HIMACHAL PRADESH': (31.10002545, 77.16659704),
#  'JAMMU AND KASHMIR': (34.29995933, 74.46665849),
#  'JHARKHAND': (23.80039349, 86.41998572),
#  'KARNATAKA': (12.57038129, 76.91999711),
#  'KERALA': (8.900372741, 76.56999263),
#  'LAKSHADWEEP': (10.56257331, 72.63686717),
#  'MADHYA PRADESH': (21.30039105, 76.13001949),
#  'MAHARASHTRA': (19.25023195, 73.16017493),
#  'MANIPUR': (24.79997072, 93.95001705),
# ...

# %% [markdown]
# # Create folium object for map

# %%
Map=folium.Map()

# %%
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Exmaple of folium map

# %%
m=folium.Map()
folium.Marker(location=(22.2587, 71.1924),popup="Hello this is sample label",draggable=True,).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Iter through all the rows of Covid data and showing them on map using latitude and longitude

# %%
for data in State_With_Covid_Data.iterrows():
    state=data[1]['State']
    if state.upper() in Location_Data.keys():
        label='State: <b>'+state+'</b><br>'\
              'Confirmed: <b>'+str(data[1]['Confirmed'])+'</b><br>'\
              'Recovered: <b>'+str(data[1]['Recovered'])+'</b><br>'\
              'Deaths: <b>'+str(data[1]['Deaths'])+'</b><br>'\
              'Active: <b>'+str(data[1]['Active'])+'</b><br>'\
              'Last Updated Time: <b>'+data[1]['Last_Updated_Time']+'</b>'
        folium.Marker(Location_Data[state.upper()],popup=label).add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
