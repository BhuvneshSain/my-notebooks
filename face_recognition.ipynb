# %% [markdown]
# <a href="https://colab.research.google.com/github/BhuvneshSain/my-notebooks/blob/master/face_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 75kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=c6d9767a98bc859d186228440f759d687f82b41cd6e1751234e3985d0ad50496
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
import requests
from IPython.display import Image
import bs4

# %%
req=requests.get('https://celebritybucks.com/developers/export/JSON')
names=set()
names=[i['name'] for i in req.json()['CelebrityValues']]
names
# Out:
# ['Kanye West',
#  'Donald Trump',
#  'Perez Hilton',
#  'Tom Hanks',
#  'Mandy Moore',
#  'Kim Kardashian',
#  ' Zach Braff',
#  'Hilary Duff',
#  'Sara Bareilles',
#  'Prince Harry',
#  'Meghan Markle',
#  'Halle Berry',
#  'Christine Teigen',
#  'Kevin Hart',
#  'Gigi Hadid',
#  '50 Cent',
#  'Scott Disick',
#  'Brad Pitt',
#  'Khloe Kardashian',
#  'Kristian Alfonso',
#  'Viola Davis',
#  'Tom Cruise',
#  'Shia LaBeouf',
#  'Gwen Stefani',
#  'Chris Evans',
#  'Kate Middleton',
#  'David Schwimmer',
#  'John Legend',
#  'Morgan Stewart',
#  'Gavin Rossdale',
#  'Scarlett Johansson',
#  'Pharrell Williams',
#  'John Boyega',
#  'Dr. Phil',
#  'Prince Charles',
#  'Sharon Osbourne',
#  'Beyonce',
#  'Kourtney Kardashian',
#  'Johnny Depp',
#  'Lily James',
#  'Garth Brooks',
#  'Christina Applegate',
#  'Kylie Jenner',
#  'Kris Jenner',
#  'Felicity Jones',
#  'Quentin Tarantino',
#  'Miley Cyrus',
#  'Brie Larson',
#  'Ariel Winter',
#  'Charlize Theron',
#  'John Travolta',
# ...

# %%
query='Bhuvnesh Sain'

url = 'https://www.google.com/search?hl=jp&q=' + query + '&btnG=Google+Search&tbs=0&safe=off&tbm=isch'
response=requests.get(url)
html=bs4.BeautifulSoup(response.content,'html.parser')
img=html.find_all('div')[8].find('img')
link=img.attrs['src']
# Out:
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTgK2BwmxgJRZXgc0KK9f8vc0oQXCnVF0_4w5rVrp4F82reYgNCIbyCy6JBgGU&s'
